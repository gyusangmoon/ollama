# %%
pip install langchain gradio
# Out:
# Requirement already satisfied: langchain in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (1.2.17)
# Collecting gradio
#   Downloading gradio-6.14.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain) (1.3.2)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain) (2.13.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (0.0.14)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (0.8.0)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\w4242\appdata\roaming\python\python314\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting audioop-lts<=0.2.2 (from gradio)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp314-cp314-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.136.1-py3-none-any.whl.metadata (28 kB)
# Collecting gradio-client==2.5.0 (from gradio)
#   Downloading gradio_client-2.5.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting hf-gradio<1.0,>=0.4.1 (from gradio)
#   Downloading hf_gradio-0.4.1-py3-none-any.whl.metadata (428 bytes)
# Collecting huggingface-hub<2.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-1.13.0-py3-none-any.whl.metadata (14 kB)
# Collecting jinja2<4.0 (from gradio)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe<4.0,>=2.0 (from gradio)
#   Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from gradio) (2.4.4)
# Collecting pandas<4.0,>=1.0 (from gradio)
#   Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting pillow<13.0,>=8.0 (from gradio)
#   Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pydub<1.0 (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart<1.0,>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.27-py3-none-any.whl.metadata (2.1 kB)
# Collecting pytz>=2017.2 (from gradio)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<2.0,>=0.40.0 (from gradio)
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Using cached uvicorn-0.46.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting fsspec (from gradio-client==2.5.0->gradio)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Using cached hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub<2.0,>=0.33.5->gradio)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\w4242\appdata\roaming\python\python314\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Collecting tzdata (from pandas<4.0,>=1.0->gradio)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting click>=8.2.1 (from typer<1.0,>=0.12->gradio)
#   Using cached click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer<1.0,>=0.12->gradio)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\users\w4242\appdata\roaming\python\python314\site-packages (from click>=8.2.1->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\w4242\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\w4242\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain) (2.6.3)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer<1.0,>=0.12->gradio)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\w4242\appdata\roaming\python\python314\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gradio-6.14.0-py3-none-any.whl (19.7 MB)
#    ---------------------------------------- 0.0/19.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.7 MB 3.4 MB/s eta 0:00:06
#    --- ------------------------------------ 1.6/19.7 MB 4.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.4/19.7 MB 4.3 MB/s eta 0:00:05
#    ------ --------------------------------- 3.1/19.7 MB 4.1 MB/s eta 0:00:04
#    -------- ------------------------------- 4.2/19.7 MB 4.1 MB/s eta 0:00:04
#    --------- ------------------------------ 4.7/19.7 MB 3.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 5.5/19.7 MB 3.9 MB/s eta 0:00:04
#    ------------- -------------------------- 6.6/19.7 MB 3.9 MB/s eta 0:00:04
#    -------------- ------------------------- 7.3/19.7 MB 4.0 MB/s eta 0:00:04
#    ----------------- ---------------------- 8.4/19.7 MB 4.0 MB/s eta 0:00:03
#    ------------------- -------------------- 9.4/19.7 MB 4.1 MB/s eta 0:00:03
#    --------------------- ------------------ 10.5/19.7 MB 4.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 11.3/19.7 MB 4.2 MB/s eta 0:00:03
#    ------------------------- -------------- 12.3/19.7 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 13.1/19.7 MB 4.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 14.2/19.7 MB 4.2 MB/s eta 0:00:02
#    ------------------------------- -------- 15.5/19.7 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.8/19.7 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------ --- 18.1/19.7 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------  19.7/19.7 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 19.7/19.7 MB 4.5 MB/s  0:00:04
# Downloading gradio_client-2.5.0-py3-none-any.whl (59 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.1-py3-none-any.whl (4.5 kB)
# Downloading huggingface_hub-1.13.0-py3-none-any.whl (660 kB)
#    ---------------------------------------- 0.0/660.6 kB ? eta -:--:--
#    ---------------------------------------- 660.6/660.6 kB 3.9 MB/s  0:00:00
# Using cached hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp314-cp314-win_amd64.whl (15 kB)
# Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 6.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.9 MB 4.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.9 MB 4.6 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.9 MB 4.6 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.9 MB 4.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.9 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 5.2 MB/s  0:00:01
# Downloading pillow-12.2.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.2 MB 4.7 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.2 MB 4.5 MB/s eta 0:00:02
#    --------------- ------------------------ 2.9/7.2 MB 4.7 MB/s eta 0:00:01
#    -------------------- ------------------- 3.7/7.2 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.2 MB 4.5 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 4.2 MB/s  0:00:01
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.27-py3-none-any.whl (29 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading brotli-1.2.0-cp314-cp314-win_amd64.whl (375 kB)
# Using cached click-8.3.3-py3-none-any.whl (110 kB)
# Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached uvicorn-0.46.0-py3-none-any.whl (70 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: pytz, pydub, brotli, tzdata, tqdm, tomlkit, shellingham, semantic-version, python-multipart, pillow, mdurl, markupsafe, hf-xet, groovy, fsspec, filelock, click, audioop-lts, annotated-doc, uvicorn, starlette, pandas, markdown-it-py, jinja2, safehttpx, rich, fastapi, typer, huggingface-hub, gradio-client, hf-gradio, gradio
#
#    ----------------------------------------  0/32 [pytz]
#    ----------------------------------------  0/32 [pytz]
#    ----------------------------------------  0/32 [pytz]
#    ----------------------------------------  0/32 [pytz]
#    ----------------------------------------  0/32 [pytz]
#    - --------------------------------------  1/32 [pydub]
#    - --------------------------------------  1/32 [pydub]
#    - --------------------------------------  1/32 [pydub]
#    - --------------------------------------  1/32 [pydub]
#    --- ------------------------------------  3/32 [tzdata]
#    --- ------------------------------------  3/32 [tzdata]
#    --- ------------------------------------  3/32 [tzdata]
#    --- ------------------------------------  3/32 [tzdata]
#    --- ------------------------------------  3/32 [tzdata]
#    --- ------------------------------------  3/32 [tzdata]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ----- ----------------------------------  4/32 [tqdm]
#    ------ ---------------------------------  5/32 [tomlkit]
#    ------ ---------------------------------  5/32 [tomlkit]
#    ------ ---------------------------------  5/32 [tomlkit]
#    ------ ---------------------------------  5/32 [tomlkit]
#    ------- --------------------------------  6/32 [shellingham]
#    -------- -------------------------------  7/32 [semantic-version]
#    -------- -------------------------------  7/32 [semantic-version]
#    ---------- -----------------------------  8/32 [python-multipart]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ----------- ----------------------------  9/32 [pillow]
#    ------------ --------------------------- 10/32 [mdurl]
#    --------------- ------------------------ 12/32 [hf-xet]
#    ---------------- ----------------------- 13/32 [groovy]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ----------------- ---------------------- 14/32 [fsspec]
#    ------------------ --------------------- 15/32 [filelock]
#    ------------------ --------------------- 15/32 [filelock]
#    ------------------ --------------------- 15/32 [filelock]
#    ------------------ --------------------- 15/32 [filelock]
#    -------------------- ------------------- 16/32 [click]
#    -------------------- ------------------- 16/32 [click]
#    -------------------- ------------------- 16/32 [click]
#    -------------------- ------------------- 16/32 [click]
#    -------------------- ------------------- 16/32 [click]
#    ---------------------- ----------------- 18/32 [annotated-doc]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ------------------------- -------------- 20/32 [starlette]
#    ------------------------- -------------- 20/32 [starlette]
#    ------------------------- -------------- 20/32 [starlette]
#    ------------------------- -------------- 20/32 [starlette]
#    ------------------------- -------------- 20/32 [starlette]
#    ------------------------- -------------- 20/32 [starlette]
#    ------------------------- -------------- 20/32 [starlette]
#    ------------------------- -------------- 20/32 [starlette]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    -------------------------- ------------- 21/32 [pandas]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    -------------------------------- ------- 26/32 [fastapi]
#    --------------------------------- ------ 27/32 [typer]
#    --------------------------------- ------ 27/32 [typer]
#    --------------------------------- ------ 27/32 [typer]
#    --------------------------------- ------ 27/32 [typer]
#    --------------------------------- ------ 27/32 [typer]
#    --------------------------------- ------ 27/32 [typer]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ----------------------------------- ---- 28/32 [huggingface-hub]
#    ------------------------------------ --- 29/32 [gradio-client]
#    ------------------------------------- -- 30/32 [hf-gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    ---------------------------------------- 32/32 [gradio]
#
# Successfully installed annotated-doc-0.0.4 audioop-lts-0.2.2 brotli-1.2.0 click-8.3.3 fastapi-0.136.1 filelock-3.29.0 fsspec-2026.4.0 gradio-6.14.0 gradio-client-2.5.0 groovy-0.1.2 hf-gradio-0.4.1 hf-xet-1.4.3 huggingface-hub-1.13.0 jinja2-3.1.6 markdown-it-py-4.0.0 markupsafe-3.0.3 mdurl-0.1.2 pandas-3.0.2 pillow-12.2.0 pydub-0.25.1 python-multipart-0.0.27 pytz-2026.1.post1 rich-15.0.0 safehttpx-0.1.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-1.0.0 tomlkit-0.14.0 tqdm-4.67.3 typer-0.25.1 tzdata-2026.2 uvicorn-0.46.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Ollama 모델 로드 및 테스트
from langchain_community.chat_models import ChatOllama

model = ChatOllama(model="gemma:2b-instruct", temperature=0)



import gradio as gr

def echo(message, history):
    response = model.invoke(message)
    return response.content

demo = gr.ChatInterface(fn=echo, title="Gemma Bot")
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
